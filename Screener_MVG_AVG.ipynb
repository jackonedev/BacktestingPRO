# %% [markdown]
# # 1) Cargar la data

# %%
import os, pickle
import pandas as pd
from tabulate import tabulate
from rich import print

# %%
def leer_nombre_ficheros(elementos_SQ, temporalidades):
    """
    Encuentra los elementos anteriores al primer match entre la lista de elementos_SQ y temporalidades.

    Args:
        elementos_SQ (list): Lista de elementos a verificar.
        temporalidades (list): Lista de temporalidades a buscar.

    Returns:
        list: Lista de listas que contienen activos encontrados dentro del elemento en elementos_SQ.
        list: Lista de listas que contienen las temporalidades encontradas en cada elemento de elementos_SQ.
    """
    id_busqueda = []
    activos_encontrados = []
    temporalidades_encontradas = []
    
    for elemento in elementos_SQ:
        elementos_previos = []
        primer_elemento = elemento.split('_')[0]
        
        for temporalidad in temporalidades:
            index = elemento.find(temporalidad)
            if index != -1:
                elementos_previos.extend(elemento[:index].split('_')[1:-1])
                temporalidades_encontradas.append(elemento[index:].split('_')[:-1])
                break
        
        id_busqueda.append(primer_elemento)
        activos_encontrados.append(elementos_previos)
    
    return id_busqueda, activos_encontrados, temporalidades_encontradas

# DECORADOR
def styler(func):
    def wrapper(*args, **kwargs):
        df = func(*args, **kwargs)
        # formato para la impresion con estilo
        keys= list(df.columns)
        values = ['{:.2f}' for i in range(len(keys))]
        format_dict = dict(zip(keys, values))
        return df.style.format(format_dict).background_gradient(cmap='PRGn')
    return wrapper

# SE UTILIZA PARA VISUALIZAR LOS DATOS DEL OBJETO correlaciones

@styler
def get_correlation(data: dict, activo: str):
    """
    Devuelve la matriz de correlaciones para un activo determinado.

    Args:
        data (dict): Diccionario con los datos de correlaciones de todos los activos.
        activo (str): Activo a buscar en el diccionario.

    Returns:
        DataFrame: Matriz de correlaciones para el activo.

    ACLARACION: El DataFrame es tipo Styler. Por lo que algunas funcionalidades propias de los DataFrame se pierden.
    """
    # Filter the data dictionary based on the activo
    filtered_data = {
        key: values[activo.upper()]
        for key, values in data.items()
    }
    # Create the DataFrame
    df = pd.DataFrame(filtered_data)
    df.columns.name = 'correlacion {}'.format(activo)
    return df

def crear_menu(id_search, activos, temporalidades):
    menu = ""

    for i in range(len(id_search)):
        assets = ' - '.join(activos[i])
        temps = ' '.join(temporalidades[i])
        menu_item = f'{id_search[i]}) {assets} : {temps}\n'
        menu += menu_item

    return menu

# %%
# PROGRAMA PRINCIPAL
# Load the data
date_path = os.path.join(os.getcwd(), 'data')

# Get the date directory
directorios = os.listdir(date_path)
print(f' Directorios guardados: {directorios}')

directorios_elegido = directorios[-1]#TODO: acá va el input para cargar los datos correspondientes
file_dir = os.path.join(date_path, directorios_elegido)#TODO: estamos eligiendo el ultimo directorio, HARDCODED es la carpeta del dia de hoy
print(f' Directorio elegido: {directorios_elegido}')
#TODO: APLICAR crear_menu para elegir el directorio a cargar
print(f' Cantidad de solicitudes guardadas: {len(os.listdir(file_dir))//4}')#WARNING: Cuando hubo errores en la descarga //4 puede arrojar errores más adelante

# obtener los nombres de los activos descargados
environment_temporalities = ['1M','1w','3d','1d','12h', '6h','4h','2h','1h','30m','15m','5m','3m', '1m']
elementos_SQ = [file for file in os.listdir(file_dir) if file.endswith('SQ.pickle')]

id_search, activos_encontrados, temporalidades = leer_nombre_ficheros(elementos_SQ, environment_temporalities)


if __name__ == '__main__':
    #TODO: crear una funcion main() que tenga argumentos de entrada, la fecha y luego los activos disponibles
    print(crear_menu(id_search, activos_encontrados, temporalidades))

    id_value = 0
    id_elegido = id_search[id_value]#TODO: acá va el input para cargar los datos correspondientes
    print(f' ID elegido: {id_elegido}')
    activos_elegidos = activos_encontrados[id_value]
    temporalidades_correspondientes = temporalidades[id_value]

    print(f' Activos elegidos: {activos_elegidos}')
    print(f' Temporalidades correspondientes: {temporalidades_correspondientes}')

    archivos_necesarios = ['.pickle','_SQ.pickle', '_CORR.pickle', '_TW.pickle']
    file_name_without_extension = f'{id_elegido}_' + '_'.join(activos_elegidos)+'_'+'_'.join(temporalidades_correspondientes)
    loaded_files = []
    for extension in archivos_necesarios:
        file_name = file_name_without_extension + extension
        file_path = os.path.join(file_dir, file_name)
        with open(file_path, 'rb') as file:
            loaded_files.append(pickle.load(file))
    data = {
        'data_raw': loaded_files[0],
        'data_SQ': loaded_files[1],
        'SQ_CORR': loaded_files[2],
        'time_window': loaded_files[3]
    }
# Out:
#  Directorios guardados: ['04_junio_2023', '05_junio_2023', '06_junio_2023', '07_junio_2023', '08_junio_2023',
# '09_junio_2023', '10_junio_2023', '11_junio_2023', '16_junio_2023']
#  Directorio elegido: 16_junio_2023
#  Cantidad de solicitudes guardadas: 1
# 1) BTC - XRP - ETH : 4h 2h 1h 30m 15m 5m 3m
#  ID elegido: 1
#  Activos elegidos: ['BTC', 'XRP', 'ETH']
#  Temporalidades correspondientes: ['4h', '2h', '1h', '30m', '15m', '5m', '3m']

# %% [raw]
# # A modo exploratorio o para explicación.
# # Output
# data.keys()
# data['data_raw'].keys()
# data['data_raw']['BTC'].keys()
# data['data_raw']['BTC']['1m']
#
#
# data['data_SQ'].keys()
# data['data_SQ'][22]['BTC'].keys()
# data['data_SQ'][22]['BTC']['1m']
#
#
# data['SQ_CORR'].keys()
# data['SQ_CORR'][22].keys()
# data['SQ_CORR'][22]['BTC']['1m']
#
#
# data['time_window'].keys()
# data['time_window']['1m'].keys()
# data['time_window']['1m'][22]

# %% [markdown]
# # 2) Mostrar las correlaciones
#
# Podría utilizarse la libreria Rich para armar tablas y exportarlas en formato txt

# %%
if __name__ == '__main__':
    asset = 'BTC'

    df = get_correlation(data['SQ_CORR'], asset)
    display(df)
# Out:
# <style type="text/css">
# #T_eb64b_row0_col0, #T_eb64b_row2_col10 {
#   background-color: #e1f2dd;
#   color: #000000;
# }
# #T_eb64b_row0_col1, #T_eb64b_row5_col3 {
#   background-color: #b3e0ad;
#   color: #000000;
# }
# #T_eb64b_row0_col2, #T_eb64b_row2_col2 {
#   background-color: #f6f5f6;
#   color: #000000;
# }
# #T_eb64b_row0_col3 {
#   background-color: #e4f2e0;
#   color: #000000;
# }
# #T_eb64b_row0_col4, #T_eb64b_row2_col4 {
#   background-color: #e5f3e1;
#   color: #000000;
# }
# #T_eb64b_row0_col5 {
#   background-color: #edf5eb;
#   color: #000000;
# }
# #T_eb64b_row0_col6 {
#   background-color: #4d0a58;
#   color: #f1f1f1;
# }
# #T_eb64b_row0_col7 {
#   background-color: #8a529a;
#   color: #f1f1f1;
# }
# #T_eb64b_row0_col8 {
#   background-color: #681f75;
#   color: #f1f1f1;
# }
# #T_eb64b_row0_col9 {
#   background-color: #9970ab;
#   color: #f1f1f1;
# }
# #T_eb64b_row0_col10 {
#   background-color: #864a95;
#   color: #f1f1f1;
# }
# #T_eb64b_row0_col11 {
#   background-color: #ae8bbd;
#   color: #f1f1f1;
# }
# #T_eb64b_row0_col12 {
#   background-color: #f7f6f7;
#   color: #000000;
# }
# #T_eb64b_row1_col0, #T_eb64b_row1_col1 {
#   background-color: #d5eecf;
#   color: #000000;
# }
# #T_eb64b_row1_col2 {
#   background-color: #f0e7f0;
#   color: #000000;
# }
# #T_eb64b_row1_col3 {
#   background-color: #ede0ed;
#   color: #000000;
# }
# #T_eb64b_row1_col4 {
#   background-color: #f0e9f1;
#   color: #000000;
# }
# #T_eb64b_row1_col5 {
#   background-color: #f2ebf2;
#   color: #000000;
# }
# #T_eb64b_row1_col6 {
#   background-color: #8f5da0;
#   color: #f1f1f1;
# }
# #T_eb64b_row1_col7 {
#   background-color: #b391c2;
#   color: #f1f1f1;
# }
# #T_eb64b_row1_col8, #T_eb64b_row1_col9, #T_eb64b_row1_col10, #T_eb64b_row1_col11, #T_eb64b_row2_col7, #T_eb64b_row2_col12, #T_eb64b_row6_col0, #T_eb64b_row6_col1, #T_eb64b_row6_col2, #T_eb64b_row6_col3, #T_eb64b_row6_col4, #T_eb64b_row6_col5, #T_eb64b_row6_col6 {
#   background-color: #40004b;
#   color: #f1f1f1;
# }
# #T_eb64b_row1_col12 {
#   background-color: #9b72ac;
#   color: #f1f1f1;
# }
# #T_eb64b_row2_col0 {
#   background-color: #b5e1af;
#   color: #000000;
# }
# #T_eb64b_row2_col1 {
#   background-color: #eadbeb;
#   color: #000000;
# }
# #T_eb64b_row2_col3 {
#   background-color: #e9f4e7;
#   color: #000000;
# }
# #T_eb64b_row2_col5 {
#   background-color: #dff1da;
#   color: #000000;
# }
# #T_eb64b_row2_col6 {
#   background-color: #ac89bc;
#   color: #f1f1f1;
# }
# #T_eb64b_row2_col8, #T_eb64b_row3_col8 {
#   background-color: #874c97;
#   color: #f1f1f1;
# }
# #T_eb64b_row2_col9 {
#   background-color: #afdfa9;
#   color: #000000;
# }
# #T_eb64b_row2_col11 {
#   background-color: #a47fb5;
#   color: #f1f1f1;
# }
# #T_eb64b_row3_col0, #T_eb64b_row3_col1, #T_eb64b_row4_col2, #T_eb64b_row4_col3, #T_eb64b_row4_col4, #T_eb64b_row4_col5, #T_eb64b_row5_col5, #T_eb64b_row5_col6, #T_eb64b_row5_col7, #T_eb64b_row6_col8, #T_eb64b_row6_col9, #T_eb64b_row6_col10, #T_eb64b_row6_col11, #T_eb64b_row6_col12 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_eb64b_row3_col2 {
#   background-color: #8aca89;
#   color: #000000;
# }
# #T_eb64b_row3_col3 {
#   background-color: #bde4b7;
#   color: #000000;
# }
# #T_eb64b_row3_col4 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_eb64b_row3_col5 {
#   background-color: #a7dba1;
#   color: #000000;
# }
# #T_eb64b_row3_col6 {
#   background-color: #f3eef3;
#   color: #000000;
# }
# #T_eb64b_row3_col7 {
#   background-color: #bea0cb;
#   color: #f1f1f1;
# }
# #T_eb64b_row3_col9 {
#   background-color: #c5e8bf;
#   color: #000000;
# }
# #T_eb64b_row3_col10 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_eb64b_row3_col11, #T_eb64b_row5_col2 {
#   background-color: #d1b8d9;
#   color: #000000;
# }
# #T_eb64b_row3_col12 {
#   background-color: #ceb5d7;
#   color: #000000;
# }
# #T_eb64b_row4_col0 {
#   background-color: #298440;
#   color: #f1f1f1;
# }
# #T_eb64b_row4_col1 {
#   background-color: #0a5625;
#   color: #f1f1f1;
# }
# #T_eb64b_row4_col6 {
#   background-color: #c1a4ce;
#   color: #000000;
# }
# #T_eb64b_row4_col7 {
#   background-color: #dbc5e0;
#   color: #000000;
# }
# #T_eb64b_row4_col8 {
#   background-color: #b897c6;
#   color: #f1f1f1;
# }
# #T_eb64b_row4_col9 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_eb64b_row4_col10 {
#   background-color: #e6f3e3;
#   color: #000000;
# }
# #T_eb64b_row4_col11 {
#   background-color: #e8d7e9;
#   color: #000000;
# }
# #T_eb64b_row4_col12 {
#   background-color: #f1eaf1;
#   color: #000000;
# }
# #T_eb64b_row5_col0 {
#   background-color: #732880;
#   color: #f1f1f1;
# }
# #T_eb64b_row5_col1 {
#   background-color: #4f0c5a;
#   color: #f1f1f1;
# }
# #T_eb64b_row5_col4 {
#   background-color: #4ea359;
#   color: #f1f1f1;
# }
# #T_eb64b_row5_col8 {
#   background-color: #93d090;
#   color: #000000;
# }
# #T_eb64b_row5_col9 {
#   background-color: #10632b;
#   color: #f1f1f1;
# }
# #T_eb64b_row5_col10 {
#   background-color: #78c07a;
#   color: #000000;
# }
# #T_eb64b_row5_col11 {
#   background-color: #f1f5ef;
#   color: #000000;
# }
# #T_eb64b_row5_col12 {
#   background-color: #eee3ee;
#   color: #000000;
# }
# #T_eb64b_row6_col7 {
#   background-color: #065022;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb64b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >correlacion BTC</th>
#       <th id="T_eb64b_level0_col0" class="col_heading level0 col0" >9</th>
#       <th id="T_eb64b_level0_col1" class="col_heading level0 col1" >12</th>
#       <th id="T_eb64b_level0_col2" class="col_heading level0 col2" >14</th>
#       <th id="T_eb64b_level0_col3" class="col_heading level0 col3" >18</th>
#       <th id="T_eb64b_level0_col4" class="col_heading level0 col4" >20</th>
#       <th id="T_eb64b_level0_col5" class="col_heading level0 col5" >22</th>
#       <th id="T_eb64b_level0_col6" class="col_heading level0 col6" >30</th>
#       <th id="T_eb64b_level0_col7" class="col_heading level0 col7" >40</th>
#       <th id="T_eb64b_level0_col8" class="col_heading level0 col8" >50</th>
#       <th id="T_eb64b_level0_col9" class="col_heading level0 col9" >60</th>
#       <th id="T_eb64b_level0_col10" class="col_heading level0 col10" >70</th>
#       <th id="T_eb64b_level0_col11" class="col_heading level0 col11" >80</th>
#       <th id="T_eb64b_level0_col12" class="col_heading level0 col12" >90</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb64b_level0_row0" class="row_heading level0 row0" >4h</th>
#       <td id="T_eb64b_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_eb64b_row0_col1" class="data row0 col1" >0.64</td>
#       <td id="T_eb64b_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_eb64b_row0_col3" class="data row0 col3" >0.55</td>
#       <td id="T_eb64b_row0_col4" class="data row0 col4" >0.55</td>
#       <td id="T_eb64b_row0_col5" class="data row0 col5" >0.54</td>
#       <td id="T_eb64b_row0_col6" class="data row0 col6" >0.50</td>
#       <td id="T_eb64b_row0_col7" class="data row0 col7" >0.49</td>
#       <td id="T_eb64b_row0_col8" class="data row0 col8" >0.53</td>
#       <td id="T_eb64b_row0_col9" class="data row0 col9" >0.28</td>
#       <td id="T_eb64b_row0_col10" class="data row0 col10" >0.29</td>
#       <td id="T_eb64b_row0_col11" class="data row0 col11" >0.46</td>
#       <td id="T_eb64b_row0_col12" class="data row0 col12" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_eb64b_level0_row1" class="row_heading level0 row1" >2h</th>
#       <td id="T_eb64b_row1_col0" class="data row1 col0" >0.54</td>
#       <td id="T_eb64b_row1_col1" class="data row1 col1" >0.57</td>
#       <td id="T_eb64b_row1_col2" class="data row1 col2" >0.44</td>
#       <td id="T_eb64b_row1_col3" class="data row1 col3" >0.48</td>
#       <td id="T_eb64b_row1_col4" class="data row1 col4" >0.50</td>
#       <td id="T_eb64b_row1_col5" class="data row1 col5" >0.51</td>
#       <td id="T_eb64b_row1_col6" class="data row1 col6" >0.56</td>
#       <td id="T_eb64b_row1_col7" class="data row1 col7" >0.53</td>
#       <td id="T_eb64b_row1_col8" class="data row1 col8" >0.50</td>
#       <td id="T_eb64b_row1_col9" class="data row1 col9" >0.18</td>
#       <td id="T_eb64b_row1_col10" class="data row1 col10" >0.21</td>
#       <td id="T_eb64b_row1_col11" class="data row1 col11" >0.35</td>
#       <td id="T_eb64b_row1_col12" class="data row1 col12" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_eb64b_level0_row2" class="row_heading level0 row2" >1h</th>
#       <td id="T_eb64b_row

# %% [markdown]
# # 4) Visualización de la data
#
# COMENTARIOS RESPECTO A LOS VALORES DE LAS MEDIAS DEL PRECIO
#
# - SMA: MEDIA MOVIL QUE PONDERA TODOS LOS PRECIOS DE CIERRE POR IGUAL
# - TRIMA: MEDIA MOVIL CONSTRUIDA A PARTIR DE LA SMA Y LA SMA DE LA SMA
# - EMA: MEDIA MOVIL QUE PONDERA DE FORMA EXPONENCIALOS LOS PRECIO DE CIERRE
# - DEMA: MEDIA MOVIL CONSTRUIDA A PARTIR DE LA EMA Y LA EMA DE LA EMA
# - TEMA: MEDIA MOVIL CONTRUIDA A PARTIR DE LA EMA Y LA EMA DE LA EMA Y LA EMA DE LA EMA DE LA EMA
# - WMA: MEDIA MOVIL PONEDARADA DE FORMA LINEAL RESPECTO AL PRECIO DE CIERRE
#
#
# ChatGPT:
#
# Ambas medias móviles, DEMA y TEMA, son consideradas indicadores más sensibles a los cambios de tendencia en comparación con las medias móviles más comunes, como la SMA y la EMA. Sin embargo, es importante recordar que ninguna media móvil es infalible y todas tienen sus ventajas y desventajas. Es recomendable probar diferentes tipos de medias móviles y combinarlas con otros indicadores y análisis para obtener una visión más completa de la situación del mercado.

# %%
# Una forma auxiliar de imprimir dataframes
# La previsualización de los datos asociados a los axis tienen que ser visualizados de esta manera

import plotly.graph_objects as go
import plotly.subplots as ms
from rich import print
from datetime import datetime
from screener.medias_moviles import get_moving_averages
#print(f'Correlación {asset} con Squeeze Momentum Indicator')
#print(df.loc[:,70:])
#print(df.loc[:,30:60])
#print(df.loc[:,9:22])

# %%
def create_multiple_cs_plot(data, asset, temp, periods, add_mvg_avg=False, mvg_avg_period=200, remove_candlestick=False, add_volume=False):
    """Función que se utiliza para crear multiples graficos en función de una temporalidad y varios periodos tomados de momentum (len)
    
    [description]

    [args]
    data (dict): diccionario con los datos de los activos
    asset (str): nombre del activo
    temp (str): temporalidad
    periods (list): lista de periodos a graficar

    [return]
    None
    """
    for period in periods:
        df = data['data_SQ'][period][asset][temp]
        corr = data['SQ_CORR'][period][asset][temp]
        # FILTRO DE LONGITUD DE DATOS
        try:
            period_window = data['time_window'][temp][period]
        except:
            period_window = df.index[0]
        candlestick_squeeze_plot(df, asset, temp, period, corr, period_window, add_mvg_avg=add_mvg_avg, mvg_avg_period=mvg_avg_period, remove_candlestick=remove_candlestick, add_volume=add_volume)

def candlestick_squeeze_plot(data, asset, temp, period, corr, period_window, add_mvg_avg=False, mvg_avg_period=200, remove_candlestick=False, add_volume=False):
    """
    Funcion que crea un grafico de velas con un squeeze plot en graficos separados

    """


    features = ['open', 'close', 'high', 'low','volume', 'value']
    df = data.loc[period_window:,features]
    if add_mvg_avg:
        df_mvg_avg = get_moving_averages(data, 'close', mvg_avg_period)
        # display(df_mvg_avg)
        df_mvg_avg = df_mvg_avg.loc[:,[f'EMA_{mvg_avg_period}', f'TRIMA_L_{mvg_avg_period}']]
        # display(df_mvg_avg)
        df_mvg_avg_10 = get_moving_averages(data, 'close', 10)
        # display(df_mvg_avg_10)
        df_mvg_avg_10 = df_mvg_avg_10.loc[:, ['EMA_10', 'WMA_10', 'DEMA_10', 'TEMA_10']]
        # display(df_mvg_avg_10)
        df_mvg_avg = df_mvg_avg.loc[period_window:, :]
        # display(df_mvg_avg)
        df_mvg_avg_10 = df_mvg_avg_10.loc[period_window:, :]
        # display(df_mvg_avg_10)
        scatters_mvg_avg = []
        for col in df_mvg_avg.columns:
            scatters_mvg_avg.append(go.Scatter(x=df_mvg_avg.index, y=df_mvg_avg[col], name=col))
        scatters_mvg_avg_10 = []
        for col in df_mvg_avg_10.columns:
            scatters_mvg_avg_10.append(go.Scatter(x=df_mvg_avg_10.index, y=df_mvg_avg_10[col], name=col))

    dist_tick = len(df)//7
    candlestick = go.Candlestick(x=df.index,
                    open=df['open'],
                    high=df['high'],
                    low=df['low'],
                    close=df['close'])

    bar_squeeze = go.Bar(x=df.index, y=df['value'], name='squeeze')
    

    if add_volume:
        bar_volume = go.Bar(x=df.index, y=df['volume'], name='volume', marker_color='blue')
        fig = ms.make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.02, row_heights=[0.8, 0.2])
        if add_mvg_avg and not remove_candlestick:
            fig.add_trace(candlestick, row=1, col=1)
            for scatter in scatters_mvg_avg:
                fig.add_trace(scatter, row=1, col=1)
            for scatter in scatters_mvg_avg_10:
                fig.add_trace(scatter, row=1, col=1)
        elif add_mvg_avg and remove_candlestick:
            for scatter in scatters_mvg_avg:
                fig.add_trace(scatter, row=1, col=1)
            for scatter in scatters_mvg_avg_10:
                fig.add_trace(scatter, row=1, col=1)
        else:
            fig.add_trace(candlestick, row=1, col=1)

        fig.add_trace(bar_volume, row=2, col=1)
        
        

    # CREACION DE LAS FIGURES
    else:
        if add_mvg_avg and not remove_candlestick:
            fig = go.Figure(data=[candlestick, *scatters_mvg_avg, *scatters_mvg_avg_10])
        elif add_mvg_avg and remove_candlestick:
            fig = go.Figure(data=[*scatters_mvg_avg, *scatters_mvg_avg_10])
        else:
            fig = go.Figure(data=[candlestick])
    
    
    
    fig2 = go.Figure(data=[bar_squeeze])


    fig.layout.xaxis.type = 'category'
    fig.layout.xaxis.rangeslider.visible = False
    fig.update_layout(
        xaxis = dict(
            tickmode = 'array',
            tickvals = df.index[dist_tick//2::dist_tick],#TODO:considerar este slide para balancear los ticks del eje x
            ticktext = df.index[:-dist_tick//2:dist_tick],#TODO:considerar este slide para balancear los ticks del eje x
        ),
        autosize=False,
        width=1200,
        height=600,
        margin=dict(
            
            l=50,
            r=50,
            b=50,
            t=50,
            pad=4
        ),
        title=f'{asset} {temp} | len squeeze: {period} | corr: {corr}',
        showlegend=False
    )
    if asset == 'BTC':
        fig.update_layout(
        paper_bgcolor="#B0BEC5",
        plot_bgcolor="#BDBDBD",
        )

    else:
        fig.update_layout(
        paper_bgcolor="LightSteelBlue",
        )

    fig2.update_layout(
        autosize=False,
        width=1200,
        height=300,
        margin=dict(
            
            l=50,
            r=50,
            b=1,
            t=10,
            pad=4
        )
    )
    if asset == 'BTC':
        fig2.update_layout(
        paper_bgcolor="#B0BEC5",
        plot_bgcolor="#BDBDBD",
        )

    else:
        fig2.update_layout(
        paper_bgcolor="LightSteelBlue")

    fig.show()
    fig2.show()

# %%
if __name__ == '__main__':
    asset = 'BTC'

    df = get_correlation(data['SQ_CORR'], asset)
    display(df)
# Out:
# <style type="text/css">
# #T_e81f5_row0_col0, #T_e81f5_row2_col10 {
#   background-color: #e1f2dd;
#   color: #000000;
# }
# #T_e81f5_row0_col1, #T_e81f5_row5_col3 {
#   background-color: #b3e0ad;
#   color: #000000;
# }
# #T_e81f5_row0_col2, #T_e81f5_row2_col2 {
#   background-color: #f6f5f6;
#   color: #000000;
# }
# #T_e81f5_row0_col3 {
#   background-color: #e4f2e0;
#   color: #000000;
# }
# #T_e81f5_row0_col4, #T_e81f5_row2_col4 {
#   background-color: #e5f3e1;
#   color: #000000;
# }
# #T_e81f5_row0_col5 {
#   background-color: #edf5eb;
#   color: #000000;
# }
# #T_e81f5_row0_col6 {
#   background-color: #4d0a58;
#   color: #f1f1f1;
# }
# #T_e81f5_row0_col7 {
#   background-color: #8a529a;
#   color: #f1f1f1;
# }
# #T_e81f5_row0_col8 {
#   background-color: #681f75;
#   color: #f1f1f1;
# }
# #T_e81f5_row0_col9 {
#   background-color: #9970ab;
#   color: #f1f1f1;
# }
# #T_e81f5_row0_col10 {
#   background-color: #864a95;
#   color: #f1f1f1;
# }
# #T_e81f5_row0_col11 {
#   background-color: #ae8bbd;
#   color: #f1f1f1;
# }
# #T_e81f5_row0_col12 {
#   background-color: #f7f6f7;
#   color: #000000;
# }
# #T_e81f5_row1_col0, #T_e81f5_row1_col1 {
#   background-color: #d5eecf;
#   color: #000000;
# }
# #T_e81f5_row1_col2 {
#   background-color: #f0e7f0;
#   color: #000000;
# }
# #T_e81f5_row1_col3 {
#   background-color: #ede0ed;
#   color: #000000;
# }
# #T_e81f5_row1_col4 {
#   background-color: #f0e9f1;
#   color: #000000;
# }
# #T_e81f5_row1_col5 {
#   background-color: #f2ebf2;
#   color: #000000;
# }
# #T_e81f5_row1_col6 {
#   background-color: #8f5da0;
#   color: #f1f1f1;
# }
# #T_e81f5_row1_col7 {
#   background-color: #b391c2;
#   color: #f1f1f1;
# }
# #T_e81f5_row1_col8, #T_e81f5_row1_col9, #T_e81f5_row1_col10, #T_e81f5_row1_col11, #T_e81f5_row2_col7, #T_e81f5_row2_col12, #T_e81f5_row6_col0, #T_e81f5_row6_col1, #T_e81f5_row6_col2, #T_e81f5_row6_col3, #T_e81f5_row6_col4, #T_e81f5_row6_col5, #T_e81f5_row6_col6 {
#   background-color: #40004b;
#   color: #f1f1f1;
# }
# #T_e81f5_row1_col12 {
#   background-color: #9b72ac;
#   color: #f1f1f1;
# }
# #T_e81f5_row2_col0 {
#   background-color: #b5e1af;
#   color: #000000;
# }
# #T_e81f5_row2_col1 {
#   background-color: #eadbeb;
#   color: #000000;
# }
# #T_e81f5_row2_col3 {
#   background-color: #e9f4e7;
#   color: #000000;
# }
# #T_e81f5_row2_col5 {
#   background-color: #dff1da;
#   color: #000000;
# }
# #T_e81f5_row2_col6 {
#   background-color: #ac89bc;
#   color: #f1f1f1;
# }
# #T_e81f5_row2_col8, #T_e81f5_row3_col8 {
#   background-color: #874c97;
#   color: #f1f1f1;
# }
# #T_e81f5_row2_col9 {
#   background-color: #afdfa9;
#   color: #000000;
# }
# #T_e81f5_row2_col11 {
#   background-color: #a47fb5;
#   color: #f1f1f1;
# }
# #T_e81f5_row3_col0, #T_e81f5_row3_col1, #T_e81f5_row4_col2, #T_e81f5_row4_col3, #T_e81f5_row4_col4, #T_e81f5_row4_col5, #T_e81f5_row5_col5, #T_e81f5_row5_col6, #T_e81f5_row5_col7, #T_e81f5_row6_col8, #T_e81f5_row6_col9, #T_e81f5_row6_col10, #T_e81f5_row6_col11, #T_e81f5_row6_col12 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e81f5_row3_col2 {
#   background-color: #8aca89;
#   color: #000000;
# }
# #T_e81f5_row3_col3 {
#   background-color: #bde4b7;
#   color: #000000;
# }
# #T_e81f5_row3_col4 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_e81f5_row3_col5 {
#   background-color: #a7dba1;
#   color: #000000;
# }
# #T_e81f5_row3_col6 {
#   background-color: #f3eef3;
#   color: #000000;
# }
# #T_e81f5_row3_col7 {
#   background-color: #bea0cb;
#   color: #f1f1f1;
# }
# #T_e81f5_row3_col9 {
#   background-color: #c5e8bf;
#   color: #000000;
# }
# #T_e81f5_row3_col10 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_e81f5_row3_col11, #T_e81f5_row5_col2 {
#   background-color: #d1b8d9;
#   color: #000000;
# }
# #T_e81f5_row3_col12 {
#   background-color: #ceb5d7;
#   color: #000000;
# }
# #T_e81f5_row4_col0 {
#   background-color: #298440;
#   color: #f1f1f1;
# }
# #T_e81f5_row4_col1 {
#   background-color: #0a5625;
#   color: #f1f1f1;
# }
# #T_e81f5_row4_col6 {
#   background-color: #c1a4ce;
#   color: #000000;
# }
# #T_e81f5_row4_col7 {
#   background-color: #dbc5e0;
#   color: #000000;
# }
# #T_e81f5_row4_col8 {
#   background-color: #b897c6;
#   color: #f1f1f1;
# }
# #T_e81f5_row4_col9 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_e81f5_row4_col10 {
#   background-color: #e6f3e3;
#   color: #000000;
# }
# #T_e81f5_row4_col11 {
#   background-color: #e8d7e9;
#   color: #000000;
# }
# #T_e81f5_row4_col12 {
#   background-color: #f1eaf1;
#   color: #000000;
# }
# #T_e81f5_row5_col0 {
#   background-color: #732880;
#   color: #f1f1f1;
# }
# #T_e81f5_row5_col1 {
#   background-color: #4f0c5a;
#   color: #f1f1f1;
# }
# #T_e81f5_row5_col4 {
#   background-color: #4ea359;
#   color: #f1f1f1;
# }
# #T_e81f5_row5_col8 {
#   background-color: #93d090;
#   color: #000000;
# }
# #T_e81f5_row5_col9 {
#   background-color: #10632b;
#   color: #f1f1f1;
# }
# #T_e81f5_row5_col10 {
#   background-color: #78c07a;
#   color: #000000;
# }
# #T_e81f5_row5_col11 {
#   background-color: #f1f5ef;
#   color: #000000;
# }
# #T_e81f5_row5_col12 {
#   background-color: #eee3ee;
#   color: #000000;
# }
# #T_e81f5_row6_col7 {
#   background-color: #065022;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e81f5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >correlacion BTC</th>
#       <th id="T_e81f5_level0_col0" class="col_heading level0 col0" >9</th>
#       <th id="T_e81f5_level0_col1" class="col_heading level0 col1" >12</th>
#       <th id="T_e81f5_level0_col2" class="col_heading level0 col2" >14</th>
#       <th id="T_e81f5_level0_col3" class="col_heading level0 col3" >18</th>
#       <th id="T_e81f5_level0_col4" class="col_heading level0 col4" >20</th>
#       <th id="T_e81f5_level0_col5" class="col_heading level0 col5" >22</th>
#       <th id="T_e81f5_level0_col6" class="col_heading level0 col6" >30</th>
#       <th id="T_e81f5_level0_col7" class="col_heading level0 col7" >40</th>
#       <th id="T_e81f5_level0_col8" class="col_heading level0 col8" >50</th>
#       <th id="T_e81f5_level0_col9" class="col_heading level0 col9" >60</th>
#       <th id="T_e81f5_level0_col10" class="col_heading level0 col10" >70</th>
#       <th id="T_e81f5_level0_col11" class="col_heading level0 col11" >80</th>
#       <th id="T_e81f5_level0_col12" class="col_heading level0 col12" >90</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e81f5_level0_row0" class="row_heading level0 row0" >4h</th>
#       <td id="T_e81f5_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_e81f5_row0_col1" class="data row0 col1" >0.64</td>
#       <td id="T_e81f5_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_e81f5_row0_col3" class="data row0 col3" >0.55</td>
#       <td id="T_e81f5_row0_col4" class="data row0 col4" >0.55</td>
#       <td id="T_e81f5_row0_col5" class="data row0 col5" >0.54</td>
#       <td id="T_e81f5_row0_col6" class="data row0 col6" >0.50</td>
#       <td id="T_e81f5_row0_col7" class="data row0 col7" >0.49</td>
#       <td id="T_e81f5_row0_col8" class="data row0 col8" >0.53</td>
#       <td id="T_e81f5_row0_col9" class="data row0 col9" >0.28</td>
#       <td id="T_e81f5_row0_col10" class="data row0 col10" >0.29</td>
#       <td id="T_e81f5_row0_col11" class="data row0 col11" >0.46</td>
#       <td id="T_e81f5_row0_col12" class="data row0 col12" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_e81f5_level0_row1" class="row_heading level0 row1" >2h</th>
#       <td id="T_e81f5_row1_col0" class="data row1 col0" >0.54</td>
#       <td id="T_e81f5_row1_col1" class="data row1 col1" >0.57</td>
#       <td id="T_e81f5_row1_col2" class="data row1 col2" >0.44</td>
#       <td id="T_e81f5_row1_col3" class="data row1 col3" >0.48</td>
#       <td id="T_e81f5_row1_col4" class="data row1 col4" >0.50</td>
#       <td id="T_e81f5_row1_col5" class="data row1 col5" >0.51</td>
#       <td id="T_e81f5_row1_col6" class="data row1 col6" >0.56</td>
#       <td id="T_e81f5_row1_col7" class="data row1 col7" >0.53</td>
#       <td id="T_e81f5_row1_col8" class="data row1 col8" >0.50</td>
#       <td id="T_e81f5_row1_col9" class="data row1 col9" >0.18</td>
#       <td id="T_e81f5_row1_col10" class="data row1 col10" >0.21</td>
#       <td id="T_e81f5_row1_col11" class="data row1 col11" >0.35</td>
#       <td id="T_e81f5_row1_col12" class="data row1 col12" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_e81f5_level0_row2" class="row_heading level0 row2" >1h</th>
#       <td id="T_e81f5_row

# %%
#4h len 12, 22

asset = 'BTC'
temp = '4h'
periods = [60, 50, 40, 30, 14, 12]
create_multiple_cs_plot(data, asset, temp, periods, add_mvg_avg=True, mvg_avg_period=55, remove_candlestick=False, add_volume=True)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Crear las figuras y subplots
fig = make_subplots(rows=2, cols=2, shared_xaxes=True, shared_yaxes=True)

# Agregar trazados a los subplots
fig.add_trace(go.Scatter(x=[1, 2, 3], y=[1, 3, 2]),
              row=1, col=1)

fig.add_trace(go.Scatter(x=[1, 2, 3], y=[2, 1, 3]),
              row=1, col=2)

fig.add_trace(go.Scatter(x=[1, 2, 3], y=[3, 2, 1]),
              row=2, col=1)

fig.add_trace(go.Scatter(x=[1, 2, 3], y=[1, 2, 3]),
              row=2, col=2)

# Actualizar las opciones de layout para mostrar la herramienta box
fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(
                    args=[{"box": {"visible": True}}],
                    label="Box",
                    method="update"
                ),
                dict(
                    args=[{"box": {"visible": False}}],
                    label="Reset",
                    method="update"
                )
            ],
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.1,
            yanchor="top"
        ),
    ]
)

# Mostrar el gráfico
fig.show()

# %%
asset = 'BTC'
temp = '1h'
periods = [50, 18, 14, 12, 9]

create_multiple_cs_plot(data, asset, temp, periods,add_mvg_avg=True, mvg_avg_period=55, remove_candlestick=False, add_volume=True)

# %%
asset = 'XRP'
temp = '30m'
periods = [70, 40, 22]

create_multiple_cs_plot(data, asset, temp, periods, add_mvg_avg=True, mvg_avg_period=200, remove_candlestick=False, add_volume=True)

# %%
asset = 'ETH'
temp = '5m'
periods = [9,12,14,18, 20, 22, 30, 50]

create_multiple_cs_plot(data, asset, temp, periods, add_mvg_avg=True, mvg_avg_period=55, remove_candlestick=False, add_volume=True)

# %% [markdown]
# # 5) Exportar tablas, registros y visualizaciones
